# %%
import numpy as np
import matplotlib.pyplot as gp

# %%
x=[1,2,3,4,6,10,11,13,14]
y=[3,5,7,10,12,15,18,20,22]

# %%
gp.plot(x,y)

# %%
a=np.polyfit(x,y,1)
b=np.poly1d(a)

# %%
gp.plot(x,b(x),'--k')
gp.plot(x,y)

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv(r'C:\Users\admin\Desktop\anaconda\GN.csv')

# %%
data
# Out:
#      checking_account_status  duration  credit_history  purpose  \
# 0                        0.0       6.0             4.0      4.0
# 1                        1.0      48.0             2.0      4.0
# 2                        3.0      12.0             4.0      7.0
# 3                        0.0      42.0             2.0      3.0
# 4                        0.0      24.0             3.0      0.0
# 5                        3.0      36.0             2.0      7.0
# 6                        3.0      24.0             2.0      3.0
# 7                        1.0      36.0             2.0      1.0
# 8                        3.0      12.0             2.0      4.0
# 9                        1.0      30.0             4.0      0.0
# 10                       1.0      12.0             2.0      0.0
# 11                       0.0      48.0             2.0      9.0
# 12                       1.0      12.0             2.0      4.0
# 13                       0.0      24.0             4.0      0.0
# ...

# %%
data.head()
# Out:
#    checking_account_status  duration  credit_history  purpose  credit_amount  \
# 0                      0.0       6.0             4.0      4.0         1169.0
# 1                      1.0      48.0             2.0      4.0         5951.0
# 2                      3.0      12.0             4.0      7.0         2096.0
# 3                      0.0      42.0             2.0      3.0         7882.0
# 4                      0.0      24.0             3.0      0.0         4870.0
#
#    savings  present_employment  installment_rate  personal  other_debtors  \
# 0      4.0                 4.0               4.0       2.0            0.0
# 1      0.0                 2.0               2.0       1.0            0.0
# 2      0.0                 3.0               2.0       2.0            0.0
# 3      0.0                 3.0               2.0       2.0            2.0
# 4      0.0                 2.0               3.0       2.0            0.0
#
# ...

# %%
x=data['credit_amount'].values
y=data['duration'].values

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)

# %%
m=len(x)

# %%
m
# Out:
# 1000

# %%
x=x.reshape((m,1))

# %%
reg=LinearRegression()
reg=reg.fit(x,y)

# %%
y_p=reg.predict(x)
plt.plot(x,y_p)

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y_p,'yellow')
plt.scatter(x,y)

# %%
d=pd.read_csv(r'C:\Users\admin\Desktop\anaconda\headbrain.csv')

# %%
d
# Out:
#      Head Size(cm^3)  Brain Weight(grams)
# 0               4512                 1530
# 1               3738                 1297
# 2               4261                 1335
# 3               3777                 1282
# 4               4177                 1590
# 5               3585                 1300
# 6               3785                 1400
# 7               3559                 1255
# 8               3613                 1355
# 9               3982                 1375
# 10              3443                 1340
# 11              3993                 1380
# 12              3640                 1355
# 13              4208                 1522
# 14              3832                 1208
# 15              3876                 1405
# 16              3497                 1358
# 17              3466                 1292
# 18              3095                 1340
# 19              4424                 1400
# 20              3878                 1357
# ...

# %%
d.head()
# Out:
#    Head Size(cm^3)  Brain Weight(grams)
# 0             4512                 1530
# 1             3738                 1297
# 2             4261                 1335
# 3             3777                 1282
# 4             4177                 1590

# %%
X = d['Head Size(cm^3)'].values
Y = d['Brain Weight(grams)'].values

# %%
plt.scatter(X,Y)

# %%
m=len(X)
X=X.reshape((m,1))

# %%
reg=LinearRegression()
reg=reg.fit(X,Y)

# %%
Y_pred=reg.predict(X)

# %%
plt.plot(X,Y_pred)

# %%
plt.plot(X,Y_pred)
plt.scatter(X,Y)

# %%
plt.scatter(X,Y_pred)

# %%
plt.scatter(X,Y)

# %%
d=pd.read_csv('GN.csv')

# %%
d
# Out:
#      checking_account_status  duration  credit_history  purpose  \
# 0                        0.0       6.0             4.0      4.0
# 1                        1.0      48.0             2.0      4.0
# 2                        3.0      12.0             4.0      7.0
# 3                        0.0      42.0             2.0      3.0
# 4                        0.0      24.0             3.0      0.0
# 5                        3.0      36.0             2.0      7.0
# 6                        3.0      24.0             2.0      3.0
# 7                        1.0      36.0             2.0      1.0
# 8                        3.0      12.0             2.0      4.0
# 9                        1.0      30.0             4.0      0.0
# 10                       1.0      12.0             2.0      0.0
# 11                       0.0      48.0             2.0      9.0
# 12                       1.0      12.0             2.0      4.0
# 13                       0.0      24.0             4.0      0.0
# ...

# %%
d.head()
# Out:
#    checking_account_status  duration  credit_history  purpose  credit_amount  \
# 0                      0.0       6.0             4.0      4.0         1169.0
# 1                      1.0      48.0             2.0      4.0         5951.0
# 2                      3.0      12.0             4.0      7.0         2096.0
# 3                      0.0      42.0             2.0      3.0         7882.0
# 4                      0.0      24.0             3.0      0.0         4870.0
#
#    savings  present_employment  installment_rate  personal  other_debtors  \
# 0      4.0                 4.0               4.0       2.0            0.0
# 1      0.0                 2.0               2.0       1.0            0.0
# 2      0.0                 3.0               2.0       2.0            0.0
# 3      0.0                 3.0               2.0       2.0            2.0
# 4      0.0                 2.0               3.0       2.0            0.0
#
# ...

# %%
x=d['credit_amount'].values
y=d['duration'].values

# %%
plt.scatter(x,y)

# %%
l=len(x)
x=x.reshape((l,1))

# %%
r=LinearRegression()
r=r.fit(x , y)

# %%
y_pr=r.predict(x)

# %%
plt.plot(x,y_pr)

# %%
plt.plot(x,y_pr, 'brown')
plt.scatter(x,y)

# %%
plt.scatter(x,y)
plt.plot(x,y_pr, 'brown')

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv(r'C:\Users\admin\Desktop\anaconda\Training-on-Artificial-Intelligence-master (1)\extracted\Training-on-Artificial-Intelligence-master\student.csv')

# %%
data
# Out:
#      call  sales
# 0      48     68
# 1      62     81
# 2      79     80
# 3      76     83
# 4      59     64
# 5      69     84
# 6      70     84
# 7      46     48
# 8      61     78
# 9      86     78
# 10     62     69
# 11     72     88
# 12     56     44
# 13     81     78
# 14     61     70
# 15     49     44
# 16     60     71
# 17     45     48
# 18     71     90
# 19     75     75
# 20     66     58
# 21     57     66
# 22     67     72
# 23     63     52
# 24     68     86
# 25     68     90
# 26     62     66
# 27     56     75
# 28     82     78
# 29     64     82
# ..    ...    ...
# 970    62     70
# 971    81     72
# 972    71     78
# 973    42     58
# 974    62     72
# 975    57     65
# 976    80     81
# 977    78     81
# 978    71     67
# 979    86     83
# 980    76     85
# 981    45     54
# 982    71     72
# 983    64     60
# 984    69     61
# 985    84     75
# 986    65     66
# 987    55     64
# 988    64     64
# 989    84     92
# ...

# %%
data.head()
# Out:
#    call  sales
# 0    48     68
# 1    62     81
# 2    79     80
# 3    76     83
# 4    59     64

# %%
x=data['call'].values
y = data["sales"].values

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)

# %%
m=len(x)

# %%
m
# Out:
# 1000

# %%
x=x.reshape((m,1))

# %%
reg=LinearRegression()
reg=reg.fit(x,y)

# %%
y_pred=reg.predict(x)

# %%
plt.plot(x,y_pred)

# %%
plt.plot(x,y_pred,'red')
plt.scatter(x,y)
plt.show()
