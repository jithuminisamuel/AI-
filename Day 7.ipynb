# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv(r'C:\Users\admin\Desktop\anaconda\headbrain.csv')

# %%
data
# Out:
#      Head Size(cm^3)  Brain Weight(grams)
# 0               4512                 1530
# 1               3738                 1297
# 2               4261                 1335
# 3               3777                 1282
# 4               4177                 1590
# 5               3585                 1300
# 6               3785                 1400
# 7               3559                 1255
# 8               3613                 1355
# 9               3982                 1375
# 10              3443                 1340
# 11              3993                 1380
# 12              3640                 1355
# 13              4208                 1522
# 14              3832                 1208
# 15              3876                 1405
# 16              3497                 1358
# 17              3466                 1292
# 18              3095                 1340
# 19              4424                 1400
# 20              3878                 1357
# ...

# %%
data.head()
# Out:
#    Head Size(cm^3)  Brain Weight(grams)
# 0             4512                 1530
# 1             3738                 1297
# 2             4261                 1335
# 3             3777                 1282
# 4             4177                 1590

# %%
X=data['Head Size(cm^3)'].values
Y=data['Brain Weight(grams)'].values

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,Y)

# %%
m=len(X)
X=X.reshape((m,1))

# %%
reg=LinearRegression()
reg=reg.fit(X,Y)

# %%
Y_pred=reg.predict(X)

# %%
plt.plot(X,Y_pred)

# %%
plt.plot(X,Y_pred)
plt.scatter(X,Y)

# %%
import pandas as pd
import matplotlib.pyplot as pt
dataset=pd.read_csv(r'C:\Users\admin\Desktop\anaconda\student.csv')

# %%
dataset
# Out:
#      call  sales
# 0      48     68
# 1      62     81
# 2      79     80
# 3      76     83
# 4      59     64
# 5      69     84
# 6      70     84
# 7      46     48
# 8      61     78
# 9      86     78
# 10     62     69
# 11     72     88
# 12     56     44
# 13     81     78
# 14     61     70
# 15     49     44
# 16     60     71
# 17     45     48
# 18     71     90
# 19     75     75
# 20     66     58
# 21     57     66
# 22     67     72
# 23     63     52
# 24     68     86
# 25     68     90
# 26     62     66
# 27     56     75
# 28     82     78
# 29     64     82
# ..    ...    ...
# 970    62     70
# 971    81     72
# 972    71     78
# 973    42     58
# 974    62     72
# 975    57     65
# 976    80     81
# 977    78     81
# 978    71     67
# 979    86     83
# 980    76     85
# 981    45     54
# 982    71     72
# 983    64     60
# 984    69     61
# 985    84     75
# 986    65     66
# 987    55     64
# 988    64     64
# 989    84     92
# ...

# %%
dataset.head()
# Out:
#    call  sales
# 0    48     68
# 1    62     81
# 2    79     80
# 3    76     83
# 4    59     64

# %%
import pandas as pd
import matplotlib.pyplot as pt
dataset=pd.read_csv(r'C:\Users\admin\Desktop\anaconda\student.csv')

x=dataset.iloc[:, 0].values
y=dataset.iloc[:, 1].values

x= x.reshape(-1, 1)
y= y.reshape(-1, 1)
from sklearn.linear_model import LinearRegression

regr=LinearRegression()
regr=regr.fit(x,y)

y_pred=regr.predict(x)

pt.plot(x,y_pred, "violet")
pt.scatter(x,y)
pt.show()
